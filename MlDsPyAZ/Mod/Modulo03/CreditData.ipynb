# %% [markdown]
# ## Importando Bibliotecas

# %%
from template_credit_data import  templateCreditaData

# %%
teste = templateCreditaData()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 teste = templateCreditaData()
#
# TypeError: __init__() should return None, not 'numpy.ndarray'
